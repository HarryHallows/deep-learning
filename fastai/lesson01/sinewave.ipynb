# %%
import numpy as np
import matplotlib.pyplot as matplot

# %% [markdown]
# ## Validating the initial setup is working as planned
# To test that jupyter notebooks are correctly setup and operational on the local machine, I've opted to pull and generate a very simple program using matlab to plot a sinewave and generate this in the notebook itself.

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

matplot.plot(x, y)
matplot.title("Sine Wave")
matplot.show()
